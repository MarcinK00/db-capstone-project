# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "root", password = "password")

# %%
connection = connector.connect(user = "root", password = "password", db = "littlelemondb_next_module") 
cursor = connection.cursor()

# %%
show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)

# %%
results = cursor.fetchall()
print(results)
# Out:
# [('customers',), ('items',), ('menus',), ('orders',), ('ordersview',)]

# %%
join_query = """
SELECT customers.customerName AS Name, 
customers.customerEmail AS Email, 
customers.customerPhone AS Phone,
orders.totalCost AS Cost
FROM customers
JOIN orders ON customers.customerID=orders.customerID
WHERE orders.totalCost > 60;
""" 
cursor.execute(join_query)
results = cursor.fetchall()
print(results)
#It is of course empty, as there was never data provided, but lack of error means that it should be correct
# Out:
# []
